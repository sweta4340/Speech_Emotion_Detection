# %%
# !pip install ffmpeg-python
import pandas as pd
import numpy as np
import tensorflow as tf
import os,time,librosa,warnings,glob
import regex as re
from sklearn.metrics import confusion_matrix,classification_report
import librosa.display
from sklearn.preprocessing import MinMaxScaler,OneHotEncoder
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.layers import Dense,Input,Add,Flatten,Dropout,Activation,AveragePooling1D,Conv1D
from keras.models import Model,Sequential,load_model
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler,EarlyStopping,ReduceLROnPlateau,ModelCheckpoint
from base64 import b64decode
from IPython.display import Audio,HTML
from scipy.io.wavfile import read as wav_read
import io
import ffmpeg
warnings.filterwarnings("ignore")
# Out:
# Requirement already satisfied: ffmpeg-python in c:\users\krishna\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: future in c:\users\krishna\anaconda3\lib\site-packages (from ffmpeg-python) (0.18.3)

# %%
mylist= os.listdir('C:/Users/KRISHNA/Desktop/SHWETA/SpringSummer 2024/Software Engineering/Project/Datasets/')

# %%
mylist
# Out:
# ['ASVP-ESD-Update',
#  'ASVP-ESD-Update.zip',
#  'Audio_features_All_pr.csv',
#  'CREMA-D',
#  'EmoDB',
#  'Emotion Speech Dataset',
#  'IEMOCAP',
#  'RAVEDESS',
#  'SAVEE',
#  'TESS',
#  '__MACOSX']

# %%
#decorator function for calculating the total time reqired to execute various function
def calc_time(func):
  def inner(*args, **kwargs):
    st = time.time()
    result = func(*args,**kwargs)
    end = time.time()-st
    print("Total time required: {:.3f} ms".format(end * 1000))
    return result
  return inner

def emodb_data():
  emodb="C:/Users/KRISHNA/Desktop/SHWETA/SpringSummer 2024/Software Engineering/Project/Datasets/EmoDB"

    # Mapping from emotion code to emotion label
  emodb_emotions = {
        'W': 'anger',
        'L': 'boredom',
        'E': 'disgust',
        'A': 'fear',
        'F': 'happy',
        'N': 'neutral',
        'T': 'sad'
    }
  emodb_emotionslist = []
  emodb_path = []

    # Get all CREMA files in the directory
  emo_files = os.listdir(emodb)

  for file in emo_files:
        # Extract the emotion code from the file name (4th character in the name)
      emotion_code = file[5]

      emotion = emodb_emotions.get(emotion_code)

      if emotion:  # Proceed only if emotion code is valid
          emodb_emotionslist.append(emotion)
          emodb_path.append(os.path.join(emodb, file))

    # Convert to DataFrame
  df_emodb = pd.DataFrame({
        "AudioPath": emodb_path,
        "Label": emodb_emotionslist
    })

  print("Length of EMOD dataset:", len(df_emodb))

  return df_emodb



#function for getting ravdess dataset details and labeling
def ravdess_data():
  #directory of the audio dataset
  ravdess = "C:/Users/KRISHNA/Desktop/SHWETA/SpringSummer 2024/Software Engineering/Project/Datasets/RAVEDESS/"
  #label ravdess data
  emotion_ravdess = {'01':'neutral','02':'calm','03':'happy','04':'sad','05':'angry','06':'fearful','07':'disgust','08':'surprised'}
  #list to store ravdess emotion
  ravdess_emotion = []
  #list to store ravdess audio path
  ravdess_path = []
  #get subfolders from the path
  ravdess_folder = os.listdir(ravdess)
  for i in ravdess_folder:
    inner_files = os.listdir(ravdess+i+'/')

    for j in inner_files:
      #get the split part which contains the emotion information then append it into lists
      emotion = j.split('-')[2]
      ravdess_path.append(ravdess+i+'/'+j)
      ravdess_emotion.append(emotion_ravdess[emotion])

  #convert to dataframe
  df_ravdess = pd.DataFrame([ravdess_path,ravdess_emotion]).T
  df_ravdess.columns = ["AudioPath","Label"]
  print("length of ravdess dataset",len(df_ravdess))

  return df_ravdess







#function for getting crema dataset details and labeling
def crema_data():
  #directory of the audio dataset
  crema = "C:/Users/KRISHNA/Desktop/SHWETA/SpringSummer 2024/Software Engineering/Project/Datasets/CREMA-D/"
  #label ravdess data
  emotion_crema = {'SAD':'sad','ANG':'angry','DIS':'disgust','FEA':'fear','HAP':'happy','NEU':'neutral'}
  #list to store crema emotion
  crema_emotion = []
  #list to store crema audio path
  crema_path = []
  #get crema files in directory
  crema_files = os.listdir(crema)
  for i in crema_files:
    emotion = i.split('_')[2]
    crema_emotion.append(emotion_crema[emotion])
    crema_path.append(crema+i)

  #convert to dataframe
  df_crema = pd.DataFrame([crema_path,crema_emotion]).T
  df_crema.columns = ["AudioPath","Label"]
  print("length of crema dataset",len(df_crema))
  return df_crema


#function for getting tess dataset and labeling
def tess_data():
  #directory of the audio dataset
  tess = "C:/Users/KRISHNA/Desktop/SHWETA/SpringSummer 2024/Software Engineering/Project/Datasets/TESS/TESS Toronto emotional speech set data/"
  tess_emotion = []
  tess_path = []
  tess_folder = os.listdir(tess)
  for i in tess_folder:

    emotion = i.split('_',1)[1]
    inner_files = os.listdir(tess+i+'/')
    for j in inner_files:
      tess_path.append(tess+i+'/'+j)
      tess_emotion.append(emotion)

  #convert to dataframe
  df_tess = pd.DataFrame([tess_path,tess_emotion]).T
  df_tess.columns = ["AudioPath","Label"]
  print("length of tess dataset",len(df_tess))

  return df_tess


def saveee_data():
    # Directory of the audio dataset
    savee = "C:/Users/KRISHNA/Desktop/SHWETA/SpringSummer 2024/Software Engineering/Project/Datasets/SAVEE/AudioData/"
    emotion_savee = {
        'a': 'anger',
        'd': 'disgust',
        'f': 'fear',
        'h': 'happiness',
        'n': 'neutral',
        'sa': 'sadness',
        'su': 'surprise'
    }
    savee_emotion = []
    savee_path = []

    # Iterate over subfolders (DC, JE, JK, KL)
    for subfolder in os.listdir(savee):
        subfolder_path = os.path.join(savee, subfolder)
        if os.path.isdir(subfolder_path):
            # Iterate over files in the subfolder
            for file in os.listdir(subfolder_path):
                file_path = os.path.join(subfolder_path, file)

                # Extract the emotion code and match it with the dictionary
                file_stem = file.split('.')[0]
                match = re.match(r"([a-z]+)(\d+)", file_stem)
                if match:
                    emotion_code = match.group(1)
                    if emotion_code in emotion_savee:
                        savee_emotion.append(emotion_savee[emotion_code])
                        savee_path.append(file_path)
                else:
                    print(f"No match found for file: {file_stem}")  # Debugging output
    # Convert to DataFrame
    df_savee = pd.DataFrame({
        "AudioPath": savee_path,
        "Label": savee_emotion
    })
    print("Length of SAVE dataset:", len(df_savee))
    return df_savee

@calc_time
def fetch_data():
  #get ravdess data
  #df_ravdess = ravdess_data()
  #get crema data
  #df_crema = crema_data()
  #get tess data
  df_tess = tess_data()
  #get savee data
  #df_savee = saveee_data()
  #get emodb data
  #df_emodb = emodb_data()
  #combine all four dataset into one single dataset and create a dataframe
  #frames = [df_ravdess,df_crema,df_tess,df_savee, df_emodb]
  frames = [df_tess]
  final_combined = pd.concat(frames)
  final_combined.reset_index(drop=True,inplace=True)
  #save the information of datasets with their path and labels into a csv file
  final_combined.to_csv("C:/Users/KRISHNA/Desktop/SHWETA/SpringSummer 2024/Software Engineering/Project/preprocesseddata.csv",index=False,header=True)
  print("Total length of the dataset is {}".format(len(final_combined)))
  return final_combined

#below are four data agumentation functions for noise, stretch, shift, pitch
#function to add noise to audio
def noise(data):
  noise_amp = 0.035* np.random.uniform()*np.amax(data)
  data = data + noise_amp*np.random.normal(size=data.shape[0])
  return data

#fuction to strech audio
def stretch(data):
    # You can specify the stretch rate inside the function if needed
    rate = 0.8  # Example stretch rate, adjust as needed
    return librosa.effects.time_stretch(data, rate)


#fucntion to shift audio range
def shift(data):
  shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
  return np.roll(data, shift_range)

#function to change pitch
def pitch(data, sampling_rate, pitch_factor=0.7):
  return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)

#fuction to extract audio features from the audio files given the information of their path
#path and label information comes from fetch_data fucntion
#also file preprocesseddata.csv stores the information of paths of audio files their label information
#the print statements are commented these statements were used to see the number of features returned as output
def extract_features(data,sample_rate):

  #zero crossing rate
  result = np.array([])
  zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
  result = np.hstack((result, zcr))
  #print('zcr',result.shape)

  #chroma shift
  stft = np.abs(librosa.stft(data))
  chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
  result = np.hstack((result, chroma_stft))
  #print('chroma',result.shape)

  #mfcc
  mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
  result = np.hstack((result, mfcc))
  #print('mfcc',result.shape)

  #rmse
  rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
  result = np.hstack((result, rms))
  #print('rmse',result.shape)

  #melspectogram
  mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)
  result = np.hstack((result, mel))
  #print('mel',result.shape)

  #rollof
  rollof = np.mean(librosa.feature.spectral_rolloff(y=data, sr=sample_rate).T, axis=0)
  result = np.hstack((result, rollof))
  #print('rollof',result.shape)

  #centroids
  centroid = np.mean(librosa.feature.spectral_centroid(y=data, sr=sample_rate).T, axis=0)
  result = np.hstack((result, centroid))
  #print('centroids',result.shape)

  #contrast
  contrast = np.mean(librosa.feature.spectral_contrast(y=data, sr=sample_rate).T, axis=0)
  result = np.hstack((result, contrast))
  #print('contrast',result.shape)

  #bandwidth
  bandwidth = np.mean(librosa.feature.spectral_bandwidth(y=data, sr=sample_rate).T, axis=0)
  result = np.hstack((result, bandwidth))
  #print('bandwidth',result.shape)

  #tonnetz
  tonnetz = np.mean(librosa.feature.tonnetz(y=data, sr=sample_rate).T, axis=0)
  result = np.hstack((result, tonnetz))
  #print('tonnetz',result.shape)

  return result

#function is used to get all augmented plus original features for given audio file
def get_features(path):
    # set the duration and offset
    # librosa.load takes audio file converts to array and returns array of audio file with its sampling rate
    data, sample_rate = librosa.load(path, duration=2.5, offset=0.6)

    # get audio features without augmentation
    res1 = extract_features(data, sample_rate)
    result = np.array(res1)

    # get audio features with noise
    noise_data = noise(data)
    res2 = extract_features(noise_data, sample_rate)
    result = np.vstack((result, res2))

    # get audio features with stretching and pitching
    data_stretch = librosa.effects.time_stretch(data, rate=0.8)  # Adjust rate as needed
    res3 = extract_features(data_stretch, sample_rate)
    result = np.vstack((result, res3))

    return result

# %%
#fucntion one by one takes aduio files from the path extracts features
#extracted audio features along with their label information are stored in a csv file
@calc_time
def Audio_features_extract():
  #this function is used to fetch the data from all the four datasets
  df = fetch_data()
  #count is used to keep a check of number of files processed
  count = 0
  #list to store audio features and their label information
  X_data, Y_label = [], []
  #zip audio path and label information and then iterate over them
  for path, emotion in zip(df["AudioPath"], df["Label"]):
    print("Number of files processed ",count)
    #get the features
    #for one audio file it get three sets of features
    #original features, features with noise(agumentation) and feature with change in stretch and pitch
    #so one audio file generates three output and the label is same for all the outputs
    feature = get_features(path)
    for ele in feature:
      X_data.append(ele)
      Y_label.append(emotion)
    count+=1
  #create a dataframe of aduio features
  Features = pd.DataFrame(X_data)
  #add label information
  Features['Label'] = Y_label
  #store the extracted features in a csv file
  Features.to_csv('C:/Users/KRISHNA/Desktop/SHWETA/SpringSummer 2024/Software Engineering/Project/Datasets/TESS_Audio_features.csv',index=False)

#this is just one time process so call this function once only to get the features
#once the features are extracted then these features are used for making model
Audio_features_extract()
# Out:
# length of tess dataset 2800
# Total length of the dataset is 2800
# Total time required: 298.020 ms
# Number of files processed  0
# Number of files processed  1
# Number of files processed  2
# Number of files processed  3
# Number of files processed  4
# Number of files processed  5
# Number of files processed  6
# Number of files processed  7
# Number of files processed  8
# Number of files processed  9
# Number of files processed  10
# Number of files processed  11
# Number of files processed  12
# Number of files processed  13
# Number of files processed  14
# Number of files processed  15
# Number of files processed  16
# Number of files processed  17
# Number of files processed  18
# Number of files processed  19
# Number of files processed  20
# Number of files processed  21
# Number of files processed  22
# Number of files processed  23
# Number of files processed  24
# Number of files processed  25
# Number of files processed  26
# Number of files processed  27
# Number of files processed  28
# Number of files processed  29
# Number of files processed  30
# Number of files processed  31
# Number of files processed  32
# Number of files processed  33
# Number of files processed  34
# Number of files processed  35
# Number of files processed  36
# Number of files processed  37
# Number of files processed  38
# Number of files processed  39
# Number of files processed  40
# Number of files processed  41
# Number of files processed  42
# Number of files processed  43
# Number of files processed  44
# Number of files processed  45
# Number of files processed  46
# Number of files processed  47
# Number of files processed  48
# Number of files processed  49
# Number of files processed  50
# Number of files processed  51
# Number of files processed  52
# Number of files processed  53
# Number of files processed  54
# Number of files processed  55
# Number of files processed  56
# Number of files processed  57
# Number of files processed  58
# Number of files processed  59
# Number of files processed  60
# Number of files processed  61
# Number of files processed  62
# Number of files processed  63
# Number of files processed  64
# Number of files processed  65
# Number of files processed  66
# Number of files processed  67
# Number of files processed  68
# Number of files processed  69
# Number of files processed  70
# Number of files processed  71
# Number of files processed  72
# Number of files processed  73
# Number of files processed  74
# Number of files processed  75
# Number of files processed  76
# Number of files processed  77
# Number of files processed  78
# Number of files processed  79
# Number of files processed  80
# Number of files processed  81
# Number of files processed  82
# Number of files processed  83
# Number of files processed  84
# Number of files processed  85
# Number of files processed  86
# Number of files processed  87
# Number of files processed  88
# Number of files processed  89
# Number of files processed  90
# Number of files processed  91
# Number of files processed  92
# Number of files processed  93
# Number of files processed  94
# Number of files processed  95
# Number of files processed  96
# Number of files processed  97
# Number of files processed  98
# Number of files processed  99
# Number of files processed  100
# Number of files processed  101
# Number of files processed  102
# Number of files processed  103
# Number of files processed  104
# Number of files processed  105
# Number of files processed  106
# Number of files processed  107
# Number of files processed  108
# Number of files processed  109
# Number of files processed  110
# Number of files processed  111
# Number of files processed  112
# Number of files processed  113
# Number of files processed  114
# Number of files processed  115
# Number of files processed  116
# Number of files processed  117
# Number of files processed  118
# Number of files processed  119
# Number of files processed  120
# Number of files processed  121
# Number of files processed  122
# Number of files processed  123
# Number of files processed  124
# Number of files processed  125
# Number of files processed  126
# Number of files processed  127
# Number of files processed  128
# Number of files processed  129
# Number of files processed  130
# Number of files processed  131
# Number of files processed  132
# Number of files processed  133
# Number of files processed  134
# Number of files processed  135
# Number of files processed  136
# Number of files processed  137
# Number of files processed  138
# Number of files processed  139
# Number of files processed  140
# Number of files processed  141
# Number of files processed  142
# Number of files processed  143
# Number of files processed  144
# Number of files processed  145
# Number of files processed  146
# Number of files processed  147
# Number of files processed  148
# Number of files processed  149
# Number of files processed  150
# Number of files processed  151
# Number of files processed  152
# Number of files processed  153
# Number of files processed  154
# Number of files processed  155
# Number of files processed  156
# Number of files processed  157
# Number of files processed  158
# Number of files processed  159
# Number of files processed  160
# Number of files processed  161
# Number of files processed  162
# Number of files processed  163
# Number of files processed  164
# Number of files processed  165
# Number of files processed  166
# Number of files processed  167
# Number of files processed  168
# Number of files processed  169
# Number of files processed  170
# Number of files processed  171
# Number of files processed  172
# Number of files processed  173
# Number of files processed  174
# Number of files processed  175
# Number of files processed  176
# Number of files processed  177
# Number of files processed  178
# Number of files processed  179
# Number of files processed  180
# Number of files processed  181
# Number of files processed  182
# Number of files processed  183
# Number of files processed  184
# Number of files processed  185
# Number of files processed  186
# Number of files processed  187
# Number of files processed  188
# Number of files processed  189
# Number of files processed  190
# Number of files processed  191
# Number of files processed  192
# Number of files processed  193
# Number of files processed  194
# Number of files processed  195
# Number of files processed  196
# Number of files processed  197
# Number of files processed  198
# Number of files processed  199
# Number of files processed  200
# Number of files processed  201
# Number of files processed  202
# Number of files processed  203
# Number of files processed  204
# Number of files processed  205
# Number of files processed  206
# Number of files processed  207
# Number of files processed  208
# Number of files processed  209
# Number of files processed  210
# Number of files processed  211
# Number of files processed  212
# Number of files processed  213
# Number of files processed  214
# Number of files processed  215
# Number of files processed  216
# Number of files processed  217
# Number of files processed  218
# Number of files processed  219
# Number of files processed  220
# Number of files processed  221
# Number of files processed  222
# Number of files processed  223
# Number of files processed  224
# Number of files processed  225
# Number of files processed  226
# Number of files processed  227
# Number of files processed  228
# Number of files processed  229
# Number of files processed  230
# Number of files processed  231
# Number of files processed  232
# Number of files processed  233
# Number of files processed  234
# Number of files processed  235
# Number of files processed  236
# Number of files processed  237
# Number of files processed  238
# Number of files processed  239
# Number of files processed  240
# Number of files processed  241
# Number of files processed  242
# Number of files processed  243
# Number of files processed  244
# Number of files processed  245
# Number of files processed  246
# Number of files processed  247
# Number of files processed  248
# Number of files processed  249
# Number of files processed  250
# Number of files processed  251
# Number of files processed  252
# Number of files processed  253
# Number of files processed  254
# Number of files processed  255
# Number of files processed  256
# Number of files processed  257
# Number of files processed  258
# Number of files processed  259
# Number of files processed  260
# Number of files processed  261
# Number of files processed  262
# Number of files processed  263
# Number of files processed  264
# Number of files processed  265
# Number of files processed  266
# Number of files processed  267
# Number of files processed  268
# Number of files processed  269
# Number of files processed  270
# Number of files processed  271
# Number of files processed  272
# Number of files processed  273
# Number of files processed  274
# Number of files processed  275
# Number of files processed  276
# Number of files processed  277
# Number of files processed  278
# Number of files processed  279
# Number of files processed  280
# Number of files processed  281
# Number of files processed  282
# Number of files processed  283
# Number of files processed  284
# Number of files processed  285
# Number of files processed  286
# Number of files processed  287
# Number of files processed  288
# Number of files processed  289
# Number of files processed  290
# Number of files processed  291
# Number of files processed  292
# Number of files processed  293
# Number of files processed  294
# Number of files processed  295
# Number of files processed  296
# Number of files processed  297
# Number of files processed  298
# Number of files processed  299
# Number of files processed  300
# Number of files processed  301
# Number of files processed  302
# Number of files processed  303
# Number of files processed  304
# Number of files processed  305
# Number of files processed  306
# Number of files processed  307
# Number of files processed  308
# Number of files processed  309
# Number of files processed  310
# Number of files processed  311
# Number of files processed  312
# Number of files processed  313
# Number of files processed  314
# Number of files processed  315
# Number of files processed  316
# Number of files processed  317
# Number of files processed  318
# Number of files processed  319
# Number of files processed  320
# Number of files processed  321
# Number of files processed  322
# Number of files processed  323
# Number of files processed  324
# Number of files processed  325
# Number of files processed  326
# Number of files processed  327
# Number of files processed  328
# Number of files processed  329
# Number of files processed  330
# Number of files processed  331
# Number of files processed  332
# Number of files processed  333
# Number of files processed  334
# Number of files processed  335
# Number of files processed  336
# Number of files processed  337
# Number of files processed  338
# Number of files processed  339
# Number of files processed  340
# Number of files processed  341
# Number of files processed  342
# Number of files processed  343
# Number of files processed  344
# Number of files processed  345
# Number of files processed  346
# Number of files processed  347
# Number of files processed  348
# Number of files processed  349
# Number of files processed  350
# Number of files processed  351
# Number of files processed  352
# Number of files processed  353
# Number of files processed  354
# Number of files processed  355
# Number of files processed  356
# Number of files processed  357
# Number of files processed  358
# Number of files processed  359
# Number of files processed  360
# Number of files processed  361
# Number of files processed  362
# Number of files processed  363
# Number of files processed  364
# Number of files processed  365
# Number of files processed  366
# Number of files processed  367
# Number of files processed  368
# Number of files processed  369
# Number of files processed  370
# Number of files processed  371
# Number of files processed  372
# Number of files processed  373
# Number of files processed  374
# Number of files processed  375
# Number of files processed  376
# Number of files processed  377
# Number of files processed  378
# Number of files processed  379
# Number of files processed  380
# Number of files processed  381
# Number of files processed  382
# Number of files processed  383
# Number of files processed  384
# Number of files processed  385
# Number of files processed  386
# Number of files processed  387
# Number of files processed  388
# Number of files processed  389
# Number of files processed  390
# Number of files processed  391
# Number of files processed  392
# Number of files processed  393
# Number of files processed  394
# Number of files processed  395
# Number of files processed  396
# Number of files processed  397
# Number of files processed  398
# Number of files processed  399
# Number of files processed  400
# Number of files processed  401
# Number of files processed  402
# Number of files processed  403
# Number of files processed  404
# Number of files processed  405
# Number of files processed  406
# Number of files processed  407
# Number of files processed  408
# Number of files processed  409
# Number of files processed  410
# Number of files processed  411
# Number of files processed  412
# Number of files processed  413
# Number of files processed  414
# Number of files processed  415
# Number of files processed  416
# Number of files processed  417
# Number of files processed  418
# Number of files processed  419
# Number of files processed  420
# Number of files processed  421
# Number of files processed  422
# Number of files processed  423
# Number of files processed  424
# Number of files processed  425
# Number of files processed  426
# Number of files processed  427
# Number of files processed  428
# Number of files processed  429
# Number of files processed  430
# Number of files processed  431
# Number of files processed  432
# Number of files processed  433
# Number of files processed  434
# Number of files processed  435
# Number of files processed  436
# Number of files processed  437
# Number of files processed  438
# Number of files processed  439
# Number of files processed  440
# Number of files processed  441
# Number of files processed  442
# Number of files processed  443
# Number of files processed  444
# Number of files processed  445
# Number of files processed  446
# Number of files processed  447
# Number of files processed  448
# Number of files processed  449
# Number of files processed  450
# Number of files processed  451
# Number of files processed  452
# Number of files processed  453
# Number of files processed  454
# Number of files processed  455
# Number of files processed  456
# Number of files processed  457
# Number of files processed  458
# Number of files processed  459
# Number of files processed  460
# Number of files processed  461
# Number of files processed  462
# Number of files processed  463
# Number of files processed  464
# Number of files processed  465
# Number of files processed  466
# Number of files processed  467
# Number of files processed  468
# Number of files processed  469
# Number of files processed  470
# Number of files processed  471
# Number of files processed  472
# Number of files processed  473
# Number of files processed  474
# Number of files processed  475
# Number of files processed  476
# Number of files processed  477
# Number of files processed  478
# Number of files processed  479
# Number of files processed  480
# Number of files processed  481
# Number of files processed  482
# Number of files processed  483
# Number of files processed  484
# Number of files processed  485
# Number of files processed  486
# Number of files processed  487
# Number of files processed  488
# Number of files processed  489
# Number of files processed  490
# Number of files processed  491
# Number of files processed  492
# Number of files processed  493
# Number of files processed  494
# Number of files processed  495
# Number of files processed  496
# Number of files processed  497
# Number of files processed  498
# Number of files processed  499
# Number of files processed  500
# Number of files processed  501
# Number of files processed  502
# Number of files processed  503
# Number of files processed  504
# Number of files processed  505
# Number of files processed  506
# Number of files processed  507
# Number of files processed  508
# Number of files processed  509
# Number of files processed  510
# Number of files processed  511
# Number of files processed  512
# Number of files processed  513
# Number of files processed  514
# Number of files processed  515
# Number of files processed  516
# Number of files processed  517
# Number of files processed  518
# Number of files processed  519
# Number of files processed  520
# Number of files processed  521
# Number of files processed  522
# Number of files processed  523
# Number of files processed  524
# Number of files processed  525
# Number of files processed  526
# Number of files processed  527
# Number of files processed  528
# Number of files processed  529
# Number of files processed  530
# Number of files processed  531
# Number of files processed  532
# Number of files processed  533
# Number of files processed  534
# Number of files processed  535
# Number of files processed  536
# Number of files processed  537
# Number of files processed  538
# Number of files processed  539
# Number of files processed  540
# Number of files processed  541
# Number of files processed  542
# Number of files processed  543
# Number of files processed  544
# Number of files processed  545
# Number of files processed  546
# Number of files processed  547
# Number of files processed  548
# Number of files processed  549
# Number of files processed  550
# Number of files processed  551
# Number of files processed  552
# Number of files processed  553
# Number of files processed  554
# Number of files processed  555
# Number of files processed  556
# Number of files processed  557
# Number of files processed  558
# Number of files processed  559
# Number of files processed  560
# Number of files processed  561
# Number of files processed  562
# Number of files processed  563
# Number of files processed  564
# Number of files processed  565
# Number of files processed  566
# Number of files processed  567
# Number of files processed  568
# Number of files processed  569
# Number of files processed  570
# Number of files processed  571
# Number of files processed  572
# Number of files processed  573
# Number of files processed  574
# Number of files processed  575
# Number of files processed  576
# Number of files processed  577
# Number of files processed  578
# Number of files processed  579
# Number of files processed  580
# Number of files processed  581
# Number of files processed  582
# Number of files processed  583
# Number of files processed  584
# Number of files processed  585
# Number of files processed  586
# Number of files processed  587
# Number of files processed  588
# Number of files processed  589
# Number of files processed  590
# Number of files processed  591
# Number of files processed  592
# Number of files processed  593
# Number of files processed  594
# Number of files processed  595
# Number of files processed  596
# Number of files processed  597
# Number of files processed  598
# Number of files processed  599
# Number of files processed  600
# Number of files processed  601
# Number of files processed  602
# Number of files processed  603
# Number of files processed  604
# Number of files processed  605
# Number of files processed  606
# Number of files processed  607
# Number of files processed  608
# Number of files processed  609
# Number of files processed  610
# Number of files processed  611
# Number of files processed  612
# Number of files processed  613
# Number of files processed  614
# Number of files processed  615
# Number of files processed  616
# Number of files processed  617
# Number of files processed  618
# Number of files processed  619
# Number of files processed  620
# Number of files processed  621
# Number of files processed  622
# Number of files processed  623
# Number of files processed  624
# Number of files processed  625
# Number of files processed  626
# Number of files processed  627
# Number of files processed  628
# Number of files processed  629
# Number of files processed  630
# Number of files processed  631
# Number of files processed  632
# Number of files processed  633
# Number of files processed  634
# Number of files processed  635
# Number of files processed  636
# Number of files processed  637
# Number of files processed  638
# Number of files processed  639
# Number of files processed  640
# Number of files processed  641
# Number of files processed  642
# Number of files processed  643
# Number of files processed  644
# Number of files processed  645
# Number of files processed  646
# Number of files processed  647
# Number of files processed  648
# Number of files processed  649
# Number of files processed  650
# Number of files processed  651
# Number of files processed  652
# Number of files processed  653
# Number of files processed  654
# Number of files processed  655
# Number of files processed  656
# Number of files processed  657
# Number of files processed  658
# Number of files processed  659
# Number of files processed  660
# Number of files processed  661
# Number of files processed  662
# Number of files processed  663
# Number of files processed  664
# Number of files processed  665
# Number of files processed  666
# Number of files processed  667
# Number of files processed  668
# Number of files processed  669
# Number of files processed  670
# Number of files processed  671
# Number of files processed  672
# Number of files processed  673
# Number of files processed  674
# Number of files processed  675
# Number of files processed  676
# Number of files processed  677
# Number of files processed  678
# Number of files processed  679
# Number of files processed  680
# Number of files processed  681
# Number of files processed  682
# Number of files processed  683
# Number of files processed  684
# Number of files processed  685
# Number of files processed  686
# Number of files processed  687
# Number of files processed  688
# Number of files processed  689
# Number of files processed  690
# Number of files processed  691
# Number of files processed  692
# Number of files processed  693
# Number of files processed  694
# Number of files processed  695
# Number of files processed  696
# Number of files processed  697
# Number of files processed  698
# Number of files processed  699
# Number of files processed  700
# Number of files processed  701
# Number of files processed  702
# Number of files processed  703
# Number of files processed  704
# Number of files processed  705
# Number of files processed  706
# Number of files processed  707
# Number of files processed  708
# Number of files processed  709
# Number of files processed  710
# Number of files processed  711
# Number of files processed  712
# Number of files processed  713
# Number of files processed  714
# Number of files processed  715
# Number of files processed  716
# Number of files processed  717
# Number of files processed  718
# Number of files processed  719
# Number of files processed  720
# Number of files processed  721
# Number of files processed  722
# Number of files processed  723
# Number of files processed  724
# Number of files processed  725
# Number of files processed  726
# Number of files processed  727
# Number of files processed  728
# Number of files processed  729
# Number of files processed  730
# Number of files processed  731
# Number of files processed  732
# Number of files processed  733
# Number of files processed  734
# Number of files processed  735
# Number of files processed  736
# Number of files processed  737
# Number of files processed  738
# Number of files processed  739
# Number of files processed  740
# Number of files processed  741
# Number of files processed  742
# Number of files processed  743
# Number of files processed  744
# Number of files processed  745
# Number of files processed  746
# Number of files processed  747
# Number of files processed  748
# Number of files processed  749
# Number of files processed  750
# Number of files processed  751
# Number of files processed  752
# Number of files processed  753
# Number of files processed  754
# Number of files processed  755
# Number of files processed  756
# Number of files processed  757
# Number of files processed  758
# Number of files processed  759
# Number of files processed  760
# Number of files processed  761
# Number of files processed  762
# Number of files processed  763
# Number of files processed  764
# Number of files processed  765
# Number of files processed  766
# Number of files processed  767
# Number of files processed  768
# Number of files processed  769
# Number of files processed  770
# Number of files processed  771
# Number of files processed  772
# Number of files processed  773
# Number of files processed  774
# Number of files processed  775
# Number of files processed  776
# Number of files processed  777
# Number of files processed  778
# Number of files processed  779
# Number of files processed  780
# Number of files processed  781
# Number of files processed  782
# Number of files processed  783
# Number of files processed  784
# Number of files processed  785
# Number of files processed  786
# Number of files processed  787
# Number of files processed  788
# Number of files processed  789
# Number of files processed  790
# Number of files processed  791
# Number of files processed  792
# Number of files processed  793
# Number of files processed  794
# Number of files processed  795
# Number of files processed  796
# Number of files processed  797
# Number of files processed  798
# Number of files processed  799
# Number of files processed  800
# Number of files processed  801
# Number of files processed  802
# Number of files processed  803
# Number of files processed  804
# Number of files processed  805
# Number of files processed  806
# Number of files processed  807
# Number of files processed  808
# Number of files processed  809
# Number of files processed  810
# Number of files processed  811
# Number of files processed  812
# Number of files processed  813
# Number of files processed  814
# Number of files processed  815
# Number of files processed  816
# Number of files processed  817
# Number of files processed  818
# Number of files processed  819
# Number of files processed  820
# Number of files processed  821
# Number of files processed  822
# Number of files processed  823
# Number of files processed  824
# Number of files processed  825
# Number of files processed  826
# Number of files processed  827
# Number of files processed  828
# Number of files processed  829
# Number of files processed  830
# Number of files processed  831
# Number of files processed  832
# Number of files processed  833
# Number of files processed  834
# Number of files processed  835
# Number of files processed  836
# Number of files processed  837
# Number of files processed  838
# Number of files processed  839
# Number of files processed  840
# Number of files processed  841
# Number of files processed  842
# Number of files processed  843
# Number of files processed  844
# Number of files processed  845
# Number of files processed  846
# Number of files processed  847
# Number of files processed  848
# Number of files processed  849
# Number of files processed  850
# Number of files processed  851
# Number of files processed  852
# Number of files processed  853
# Number of files processed  854
# Number of files processed  855
# Number of files processed  856
# Number of files processed  857
# Number of files processed  858
# Number of files processed  859
# Number of files processed  860
# Number of files processed  861
# Number of files processed  862
# Number of files processed  863
# Number of files processed  864
# Number of files processed  865
# Number of files processed  866
# Number of files processed  867
# Number of files processed  868
# Number of files processed  869
# Number of files processed  870
# Number of files processed  871
# Number of files processed  872
# Number of files processed  873
# Number of files processed  874
# Number of files processed  875
# Number of files processed  876
# Number of files processed  877
# Number of files processed  878
# Number of files processed  879
# Number of files processed  880
# Number of files processed  881
# Number of files processed  882
# Number of files processed  883
# Number of files processed  884
# Number of files processed  885
# Number of files processed  886
# Number of files processed  887
# Number of files processed  888
# Number of files processed  889
# Number of files processed  890
# Number of files processed  891
# Number of files processed  892
# Number of files processed  893
# Number of files processed  894
# Number of files processed  895
# Number of files processed  896
# Number of files processed  897
# Number of files processed  898
# Number of files processed  899
# Number of files processed  900
# Number of files processed  901
# Number of files processed  902
# Number of files processed  903
# Number of files processed  904
# Number of files processed  905
# Number of files processed  906
# Number of files processed  907
# Number of files processed  908
# Number of files processed  909
# Number of files processed  910
# Number of files processed  911
# Number of files processed  912
# Number of files processed  913
# Number of files processed  914
# Number of files processed  915
# Number of files processed  916
# Number of files processed  917
# Number of files processed  918
# Number of files processed  919
# Number of files processed  920
# Number of files processed  921
# Number of files processed  922
# Number of files processed  923
# Number of files processed  924
# Number of files processed  925
# Number of files processed  926
# Number of files processed  927
# Number of files processed  928
# Number of files processed  929
# Number of files processed  930
# Number of files processed  931
# Number of files processed  932
# Number of files processed  933
# Number of files processed  934
# Number of files processed  935
# Number of files processed  936
# Number of files processed  937
# Number of files processed  938
# Number of files processed  939
# Number of files processed  940
# Number of files processed  941
# Number of files processed  942
# Number of files processed  943
# Number of files processed  944
# Number of files processed  945
# Number of files processed  946
# Number of files processed  947
# Number of files processed  948
# Number of files processed  949
# Number of files processed  950
# Number of files processed  951
# Number of files processed  952
# Number of files processed  953
# Number of files processed  954
# Number of files processed  955
# Number of files processed  956
# Number of files processed  957
# Number of files processed  958
# Number of files processed  959
# Number of files processed  960
# Number of files processed  961
# Number of files processed  962
# Number of files processed  963
# Number of files processed  964
# Number of files processed  965
# Number of files processed  966
# Number of files processed  967
# Number of files processed  968
# Number of files processed  969
# Number of files processed  970
# Number of files processed  971
# Number of files processed  972
# Number of files processed  973
# Number of files processed  974
# Number of files processed  975
# Number of files processed  976
# Number of files processed  977
# Number of files processed  978
# Number of files processed  979
# Number of files processed  980
# Number of files processed  981
# Number of files processed  982
# Number of files processed  983
# Number of files processed  984
# Number of files processed  985
# Number of files processed  986
# Number of files processed  987
# Number of files processed  988
# Number of files processed  989
# Number of files processed  990
# Number of files processed  991
# Number of files processed  992
# Number of files processed  993
# Number of files processed  994
# Number of files processed  995
# Number of files processed  996
# Number of files processed  997
# Number of files processed  998
# Number of files processed  999
# Number of files processed  1000
# Number of files processed  1001
# Number of files processed  1002
# Number of files processed  1003
# Number of files processed  1004
# Number of files processed  1005
# Number of files processed  1006
# Number of files processed  1007
# Number of files processed  1008
# Number of files processed  1009
# Number of files processed  1010
# Number of files processed  1011
# Number of files processed  1012
# Number of files processed  1013
# Number of files processed  1014
# Number of files processed  1015
# Number of files processed  1016
# Number of files processed  1017
# Number of files processed  1018
# Number of files processed  1019
# Number of files processed  1020
# Number of files processed  1021
# Number of files processed  1022
# Number of files processed  1023
# Number of files processed  1024
# Number of files processed  1025
# Number of files processed  1026
# Number of files processed  1027
# Number of files processed  1028
# Number of files processed  1029
# Number of files processed  1030
# Number of files processed  1031
# Number of files processed  1032
# Number of files processed  1033
# Number of files processed  1034
# Number of files processed  1035
# Number of files processed  1036
# Number of files processed  1037
# Number of files processed  1038
# Number of files processed  1039
# Number of files processed  1040
# Number of files processed  1041
# Number of files processed  1042
# Number of files processed  1043
# Number of files processed  1044
# Number of files processed  1045
# Number of files processed  1046
# Number of files processed  1047
# Number of files processed  1048
# Number of files processed  1049
# Number of files processed  1050
# Number of files processed  1051
# Number of files processed  1052
# Number of files processed  1053
# Number of files processed  1054
# Number of files processed  1055
# Number of files processed  1056
# Number of files processed  1057
# Number of files processed  1058
# Number of files processed  1059
# Number of files processed  1060
# Number of files processed  1061
# Number of files processed  1062
# Number of files processed  1063
# Number of files processed  1064
# Number of files processed  1065
# Number of files processed  1066
# Number of files processed  1067
# Number of files processed  1068
# Number of files processed  1069
# Number of files processed  1070
# Number of files processed  1071
# Number of files processed  1072
# Number of files processed  1073
# Number of files processed  1074
# Number of files processed  1075
# Number of files processed  1076
# Number of files processed  1077
# Number of files processed  1078
# Number of files processed  1079
# Number of files processed  1080
# Number of files processed  1081
# Number of files processed  1082
# Number of files processed  1083
# Number of files processed  1084
# Number of files processed  1085
# Number of files processed  1086
# Number of files processed  1087
# Number of files processed  1088
# Number of files processed  1089
# Number of files processed  1090
# Number of files processed  1091
# Number of files processed  1092
# Number of files processed  1093
# Number of files processed  1094
# Number of files processed  1095
# Number of files processed  1096
# Number of files processed  1097
# Number of files processed  1098
# Number of files processed  1099
# Number of files processed  1100
# Number of files processed  1101
# Number of files processed  1102
# Number of files processed  1103
# Number of files processed  1104
# Number of files processed  1105
# Number of files processed  1106
# Number of files processed  1107
# Number of files processed  1108
# Number of files processed  1109
# Number of files processed  1110
# Number of files processed  1111
# Number of files processed  1112
# Number of files processed  1113
# Number of files processed  1114
# Number of files processed  1115
# Number of files processed  1116
# Number of files processed  1117
# Number of files processed  1118
# Number of files processed  1119
# Number of files processed  1120
# Number of files processed  1121
# Number of files processed  1122
# Number of files processed  1123
# Number of files processed  1124
# Number of files processed  1125
# Number of files processed  1126
# Number of files processed  1127
# Number of files processed  1128
# Number of files processed  1129
# Number of files processed  1130
# Number of files processed  1131
# Number of files processed  1132
# Number of files processed  1133
# Number of files processed  1134
# Number of files processed  1135
# Number of files processed  1136
# Number of files processed  1137
# Number of files processed  1138

# %%
df = pd.read_csv('C:/Users/KRISHNA/Desktop/SHWETA/SpringSummer 2024/Software Engineering/Project/Datasets/TESS_Audio_features.csv')

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.085690  0.671934  0.694386  0.672386  0.675260  0.674322  0.579565
# 1  0.333770  0.797108  0.782480  0.807224  0.827673  0.849722  0.721145
# 2  0.087011  0.669836  0.667529  0.644506  0.662008  0.684189  0.587950
# 3  0.078444  0.718596  0.729192  0.653268  0.665332  0.687527  0.602966
# 4  0.249362  0.829492  0.814746  0.797276  0.832798  0.834370  0.721018
#
#           7         8         9  ...        169        170          171  \
# 0  0.578604  0.647424  0.650719  ...  18.746176  64.114904  1731.887285
# 1  0.657037  0.713000  0.705108  ...  14.599600  13.487766  3169.757903
# 2  0.573317  0.647922  0.634995  ...  19.529557  63.937932  1762.273934
# 3  0.577669  0.618406  0.681478  ...  17.493382  65.144855  1688.484810
# 4  0.662350  0.694647  0.733950  ...  14.019852  13.964472  3175.640469
#
#         172       173       174       175       176       177    Label
# 0  0.003534  0.008039 -0.032030 -0.051590  0.013397  0.002890    angry
# 1  0.002917  0.005644  0.005008 -0.043510  0.005535 -0.003544    angry
# 2 -0.004329  0.012501 -0.003171 -0.070005  0.012059 -0.005641    angry
# 3 -0.008084 -0.022689 -0.040267 -0.029069  0.004925  0.014550  disgust
# 4 -0.009975 -0.021236 -0.017016 -0.038512  0.007312  0.003584  disgust
#
# [5 rows x 179 columns]

# %%
print("\nUnique count of labels or emotions\n",df["Label"].value_counts())
# Out:
# Unique count of labels or emotions
#  Label
# angry      3813
# disgust    3813
# fear       3813
# happy      3813
# sad        3813
# neutral    3261
# Name: count, dtype: int64

# %%
  df["Label"] = df["Label"].str.replace("sadness", "sad", case = True)
  df["Label"] = df["Label"].str.replace("happiness", "happy", case = True)
  df["Label"] = df["Label"].str.replace("Fear", "fear", case = True)
  df["Label"] = df["Label"].str.replace("Sad", "sad", case = True)
  df["Label"] = df["Label"].str.replace("Pleasant_surprise", "surprise", case = True)
  df["Label"] = df["Label"].str.replace("pleasant_surprised", "surprise", case = True)
  df["Label"] = df["Label"].str.replace("surprised", "surprise", case = True)
  df["Label"] = df["Label"].str.replace("fearful", "fear", case = True)
  df["Label"] = df["Label"].str.replace("anger", "angry", case = True)
  #drop labels surprized and clam
  #these label dosent contain sufficent amount of data and can lead to missclassification
  print("\nUnique count of labels or emotions\n",df["Label"].value_counts())
  #drop labels or emotions which can lead to misclassifications
  df.drop((np.where(df['Label'].isin(["surprise","calm","boredom"]))[0]), inplace = True)
  print("\nUnique count of labels or emotions after dropping selected labels\n",df["Label"].value_counts())
  print("\nlength of the total data is {}".format(len(df)))

# %%
  from sklearn.preprocessing import StandardScaler, LabelEncoder
  data=df[df.columns[0:-1]].values
  #perform one hot encoding on labels
  encoder = OneHotEncoder()
  label_encoder = LabelEncoder()
  #fetch the last column of labels and perform one hot encoding on them
  label=df["Label"].values
  label = label_encoder.fit_transform(label)
  #min max scaler is used to normalize the data
  scaler = MinMaxScaler()
  data=scaler.fit_transform(data)
  #split the dataframe into train and test 80% train, 10% validation and 10% test datasets
  x_train, x_test, y_train, y_test = train_test_split(data, label, test_size=0.20, random_state=42,shuffle=True)

# %% [markdown]
# # SVM with RBF kernel

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score

param_grid = {
    'C': [0.1, 1, 10, 100, 1000],
    'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
    'kernel': ['rbf']
}

# Perform GridSearchCV to find the best hyperparameters
#grid_search = GridSearchCV(SVC(), param_grid)
#grid_search.fit(x_train, y_train)

# Get the best model
#best_svm = grid_search.best_estimator_

#best_svm=SVC(kernel="rbf",gamma=1,C=100)
best_svm=SVC(kernel="rbf",gamma=10,C=100)
best_svm.fit(x_train, y_train)

# Predict on the test set
y_pred = best_svm.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred, target_names=label_encoder.classes_)

#print(f"Best Parameters: {grid_search.best_params_}")
print(f"Accuracy: {accuracy}")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.6739811912225705
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.63      0.88      0.73       787
#      disgust       0.67      0.62      0.64       777
#         fear       0.69      0.53      0.60       734
#        happy       0.66      0.64      0.65       709
#      neutral       0.71      0.60      0.65       674
#          sad       0.72      0.75      0.73       785
#
#     accuracy                           0.67      4466
#    macro avg       0.68      0.67      0.67      4466
# weighted avg       0.68      0.67      0.67      4466

# %%
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(n_estimators=100, random_state=42)
random_forest.fit(x_train, y_train)

# Predict on the test set
y_pred = random_forest.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred, target_names=label_encoder.classes_)

print(f"Accuracy: {accuracy}")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.6300940438871473
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.74      0.80      0.77       787
#      disgust       0.59      0.49      0.53       777
#         fear       0.77      0.47      0.58       734
#        happy       0.57      0.63      0.60       709
#      neutral       0.58      0.65      0.61       674
#          sad       0.58      0.74      0.65       785
#
#     accuracy                           0.63      4466
#    macro avg       0.64      0.63      0.62      4466
# weighted avg       0.64      0.63      0.63      4466

# %%
cm = confusion_matrix(y_test, y_pred)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

gradient_booster = GradientBoostingClassifier(learning_rate=0.1)

gradient_booster.fit(x_train,y_train)
y_pred = gradient_booster.predict(x_test)

print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
k = 1  # Choose an appropriate k
knn = KNeighborsClassifier(n_neighbors=k)

# Train the classifier
knn.fit(x_train, y_train)

# Predict on the test set
y_pred = knn.predict(x_test)

# Evaluate the accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))

# %%
cm = confusion_matrix(y_test, y_pred)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# Points to be noted: Random Forest was effectively able to classify angry and sad emotions whereas KNN was able to classify the remaining 4. So combining predictionsof both of these can be helpful in classifying all of them.

# %% [markdown]
# # Random Forest and SVM with Bagging approach

# %%
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
# Define the base models
svm=SVC(kernel="rbf",gamma=10,C=100)
random_forest = RandomForestClassifier(n_estimators=100, random_state=42)

# Define the bagging classifier for SVM
bagging_svm = BaggingClassifier(estimator=svm,n_estimators=10, random_state=42)

# Define the bagging classifier for Random Forest
bagging_rf = BaggingClassifier(estimator=random_forest, n_estimators=10, random_state=42)

# Train the bagging models
bagging_svm.fit(x_train, y_train)
bagging_rf.fit(x_train, y_train)

# Predict on the test set using both models
y_pred_svm = bagging_svm.predict(x_test)
y_pred_rf = bagging_rf.predict(x_test)

# Combine predictions to create meta-features
meta_features = np.column_stack((y_pred_svm, y_pred_rf))

# %%
from sklearn.ensemble import GradientBoostingClassifier
# Define meta-learner (can be any classifier)

   # "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    # "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, random_state=42)
    # SVM: SVC(kernel='linear', random_state=42) 

meta_learner =  KNeighborsClassifier(n_neighbors=100)
# Train meta-learner on meta-features and true labels
meta_learner.fit(meta_features, y_test)

# Use the trained meta-learner to make predictions on new data (test set)
# Assuming X_test is available
y_pred_stacking = meta_learner.predict(meta_features)

# Evaluate stacking model
accuracy_stacking = accuracy_score(y_test, y_pred_stacking)
print(f"Accuracy (Stacking): {accuracy_stacking}")
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))

# %%
#RANDOM FOREST AS THE META-LEARNER
cm = confusion_matrix(y_test, y_pred_stacking)
# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Random Forest and SVM with Boosting Approach

# %%
# Define the base models
svm=SVC(probability=True,kernel="rbf",gamma=10,C=100)
random_forest = RandomForestClassifier(n_estimators=100, random_state=42)

# Step 1: Train the RF model on the original dataset
random_forest.fit(x_train, y_train)

# Step 2: Evaluate the RF model and get the misclassified samples
y_pred_rf = random_forest.predict(x_train)
misclassified_samples = (y_pred_rf!= y_train)

# Step 3: Increase weights of misclassified samples (custom weighting scheme)
sample_weights = np.ones(len(y_train))
sample_weights[misclassified_samples] *= 2  # Double the weights of misclassified samples

# Step 4: Train the SVM model on the weighted samples
svm.fit(x_train, y_train, sample_weight=sample_weights)

# Step 5: Get predictions from both models on the test set
svm_probs = svm.predict_proba(x_test)
rf_probs = random_forest.predict_proba(x_test)

# Step 6: Combine the probabilities using a weighted average (equal weights for simplicity)
combined_probs = (svm_probs + rf_probs) / 2

# Step 7: Convert combined probabilities to final predictions
y_pred_combined = np.argmax(combined_probs, axis=1)

# Evaluate the combined model
accuracy_combined = accuracy_score(y_test, y_pred_combined)
print(f"Accuracy (Boosted SVM and RF): {accuracy_combined}")
print(classification_report(y_test, y_pred_combined, target_names=label_encoder.classes_))

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred_combined)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix (Boosted SVM and RF RAVEDESS)')
plt.show()
# Out:
# Accuracy (Boosted SVM and RF): 0.7337662337662337
#               precision    recall  f1-score   support
#
#        angry       0.74      0.88      0.80       787
#      disgust       0.74      0.66      0.70       777
#         fear       0.78      0.61      0.69       734
#        happy       0.73      0.72      0.72       709
#      neutral       0.71      0.70      0.71       674
#          sad       0.70      0.82      0.76       785
#
#     accuracy                           0.73      4466
#    macro avg       0.74      0.73      0.73      4466
# weighted avg       0.74      0.73      0.73      4466

# %%
meta_features = np.hstack((svm_probs + rf_probs))

# %%
meta_features[0]

# %%
len(y_test)

# %%
# Combine predictions to create meta-features
meta_features = np.hstack((svm_probs + rf_probs))
meta_learner =  RandomForestClassifier(n_estimators=100, random_state=42) 
# Train meta-learner on meta-features and true labels
meta_learner.fit(meta_features, y_test)

# Use the trained meta-learner to make predictions on new data (test set)
# Assuming X_test is available
y_pred_stacking = meta_learner.predict(meta_features)

# Evaluate stacking model
accuracy_stacking = accuracy_score(y_test, y_pred_stacking)
print(f"Accuracy (Stacking): {accuracy_stacking}")
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred_combined)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix (Boosted SVM and RF)')
plt.show()
